# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from dataset.fairface import dataset

# %%
df = dataset['train'].to_pandas()

print(df.head())
# Out:
#                                                image  age  gender  race  \
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    6       0     0
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    4       1     1
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    1       1     2
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    3       1     1
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    3       1     1
#
#    service_test
# 0          True
# 1         False
# 2         False
# 3          True
# 4          True

# %%
df['gender'].value_counts().plot(kind='bar',figsize=(3,4), title='Gender Distribution')
# Out:
# <Axes: title={'center': 'Gender Distribution'}, xlabel='gender'>

# %%
race_names = {
    0: "White",
    1: "Black",
    2: "Indian",
    3: "East Asian",
    4: "Southeast Asian",
    5: "Middle Eastern",
    6: "Latino Hispanic"
}
df['race'].value_counts().plot(kind='bar',figsize=(3,4), title='race Distribution')
# Out:
# <Axes: title={'center': 'race Distribution'}, xlabel='race'>

# %%
df['age'].value_counts().plot(kind='bar',figsize=(3,4), title='age Distribution')
# Out:
# <Axes: title={'center': 'age Distribution'}, xlabel='age'>
